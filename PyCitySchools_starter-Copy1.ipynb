# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
total_schools = school_data["School ID"].count()
total_schools
# Out:
# 15

# %%
total_students = school_data["size"].sum()
total_students
# Out:
# 39170

# %%
total_budget = school_data["budget"].sum()
total_budget
# Out:
# 24649428

# %%
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
average_math=school_data_complete["math_score"].mean()
average_math
# Out:
# 78.98537145774827

# %%
average_reading=school_data_complete["reading_score"].mean()
average_reading
# Out:
# 81.87784018381414

# %%
average_overall= (average_math + average_reading) / 2
average_overall
# Out:
# 80.43160582078121

# %%
math_70= school_data_complete["math_score"] > 70
math_70
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 39165     True
# 39166    False
# 39167     True
# 39168     True
# 39169     True
# Name: math_score, Length: 39170, dtype: bool

# %%
math_70.value_counts()
# Out:
# True     28356
# False    10814
# Name: math_score, dtype: int64

# %%
math_70_students= math_70.sum()
math_70_students
# Out:
# 28356

# %%
percentage_math_70 = math_70_students/ total_students 
percentage_math_70
# Out:
# 0.7239213683941792

# %%
reading_70= school_data_complete["reading_score"] > 70
reading_70
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 39165     True
# 39166     True
# 39167     True
# 39168     True
# 39169     True
# Name: reading_score, Length: 39170, dtype: bool

# %%
reading_70_students= reading_70.sum()
reading_70_students
# Out:
# 32500

# %%
percentage_reading_70 = reading_70_students / total_students
percentage_reading_70
# Out:
# 0.8297166198621394

# %%
dis_summary= pd.DataFrame ({
    
    "Total Schools": [total_schools],
    "Total Students": [total_students],
    "Total Budget": [total_budget],
    "Average Math Score": [average_math],
    "Average Reading Score": [average_reading],
    "% Passing Math": [percentage_math_70],
    "% Passing Reading":[percentage_reading_70],
    "% Overall Passing Rate": [average_overall]
    
    
})
dis_summary
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0               81.87784        0.723921           0.829717
#
#    % Overall Passing Rate
# 0               80.431606

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)
#
# * Create a dataframe to hold the above results

# %%
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
 df = school_data_complete.set_index("school_name")
                    
df.head()
# Out:
#                    Student ID       student_name gender grade  reading_score  \
# school_name
# Huang High School           0       Paul Bradley      M   9th             66
# Huang High School           1       Victor Smith      M  12th             94
# Huang High School           2    Kevin Rodriguez      M  12th             90
# Huang High School           3  Dr. Richard Scott      M  12th             67
# Huang High School           4         Bonnie Ray      F   9th             97
#
#                    math_score  School ID      type  size   budget
# school_name
# Huang High School          79          0  District  2917  1910635
# Huang High School          61          0  District  2917  1910635
# Huang High School          60          0  District  2917  1910635
# Huang High School          58          0  District  2917  1910635
# Huang High School          84          0  District  2917  1910635

# %%
index = school_data.set_index (["school_name"])["type"]
index
# Out:
# school_name
# Huang High School        District
# Figueroa High School     District
# Shelton High School       Charter
# Hernandez High School    District
# Griffin High School       Charter
# Wilson High School        Charter
# Cabrera High School       Charter
# Bailey High School       District
# Holden High School        Charter
# Pena High School          Charter
# Wright High School        Charter
# Rodriguez High School    District
# Johnson High School      District
# Ford High School         District
# Thomas High School        Charter
# Name: type, dtype: object

# %%
total_students_school = school_data_complete["school_name"].value_counts()
total_students_school
# Out:
# Bailey High School       4976
# Johnson High School      4761
# Hernandez High School    4635
# Rodriguez High School    3999
# Figueroa High School     2949
# Huang High School        2917
# Ford High School         2739
# Wilson High School       2283
# Cabrera High School      1858
# Wright High School       1800
# Shelton High School      1761
# Thomas High School       1635
# Griffin High School      1468
# Pena High School          962
# Holden High School        427
# Name: school_name, dtype: int64

# %%
total_budget_school = school_data_complete.groupby("school_name").mean() ['budget']
total_budget_school
# Out:
# school_name
# Bailey High School       3124928.0
# Cabrera High School      1081356.0
# Figueroa High School     1884411.0
# Ford High School         1763916.0
# Griffin High School       917500.0
# Hernandez High School    3022020.0
# Holden High School        248087.0
# Huang High School        1910635.0
# Johnson High School      3094650.0
# Pena High School          585858.0
# Rodriguez High School    2547363.0
# Shelton High School      1056600.0
# Thomas High School       1043130.0
# Wilson High School       1319574.0
# Wright High School       1049400.0
# Name: budget, dtype: float64

# %%
per_student_budget =  total_budget_school / total_students_school
per_student_budget
# Out:
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
average_math_school= school_data_complete.groupby("school_name").mean() ["math_score"]
average_math_school
{}
# Out:
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: math_score, dtype: float64

# %%
average_reading_school= school_data_complete.groupby("school_name").mean() ["reading_score"]
average_reading_school
# Out:
# school_name
# Bailey High School       81.033963
# Cabrera High School      83.975780
# Figueroa High School     81.158020
# Ford High School         80.746258
# Griffin High School      83.816757
# Hernandez High School    80.934412
# Holden High School       83.814988
# Huang High School        81.182722
# Johnson High School      80.966394
# Pena High School         84.044699
# Rodriguez High School    80.744686
# Shelton High School      83.725724
# Thomas High School       83.848930
# Wilson High School       83.989488
# Wright High School       83.955000
# Name: reading_score, dtype: float64

# %%
math_percentage_70= school_data_complete[(school_data_complete["math_score"] >= 70)] 
percentage_math_school= math_percentage_70.groupby("school_name").count() ["student_name"]

percentage_math_school
# Out:
# school_name
# Bailey High School       3318
# Cabrera High School      1749
# Figueroa High School     1946
# Ford High School         1871
# Griffin High School      1371
# Hernandez High School    3094
# Holden High School        395
# Huang High School        1916
# Johnson High School      3145
# Pena High School          910
# Rodriguez High School    2654
# Shelton High School      1653
# Thomas High School       1525
# Wilson High School       2143
# Wright High School       1680
# Name: student_name, dtype: int64

# %%
percentage_math_school_2 =( percentage_math_school  / total_students_school) 
percentage_math_school_2
# Out:
# Bailey High School       0.666801
# Cabrera High School      0.941335
# Figueroa High School     0.659885
# Ford High School         0.683096
# Griffin High School      0.933924
# Hernandez High School    0.667530
# Holden High School       0.925059
# Huang High School        0.656839
# Johnson High School      0.660576
# Pena High School         0.945946
# Rodriguez High School    0.663666
# Shelton High School      0.938671
# Thomas High School       0.932722
# Wilson High School       0.938677
# Wright High School       0.933333
# dtype: float64

# %%
reading_percentage_70= school_data_complete[(school_data_complete["reading_score"] >= 70)] 
percentage_reading_school= reading_percentage_70.groupby("school_name").count() ["student_name"]

percentage_reading_school
# Out:
# school_name
# Bailey High School       4077
# Cabrera High School      1803
# Figueroa High School     2381
# Ford High School         2172
# Griffin High School      1426
# Hernandez High School    3748
# Holden High School        411
# Huang High School        2372
# Johnson High School      3867
# Pena High School          923
# Rodriguez High School    3208
# Shelton High School      1688
# Thomas High School       1591
# Wilson High School       2204
# Wright High School       1739
# Name: student_name, dtype: int64

# %%
percentage_reading_school_2 =( percentage_reading_school  / total_students_school) 
percentage_reading_school_2
# Out:
# Bailey High School       0.819333
# Cabrera High School      0.970398
# Figueroa High School     0.807392
# Ford High School         0.792990
# Griffin High School      0.971390
# Hernandez High School    0.808630
# Holden High School       0.962529
# Huang High School        0.813164
# Johnson High School      0.812224
# Pena High School         0.959459
# Rodriguez High School    0.802201
# Shelton High School      0.958546
# Thomas High School       0.973089
# Wilson High School       0.965396
# Wright High School       0.966111
# dtype: float64

# %%
overall_rate= (percentage_reading_school_2 + percentage_math_school_2) / 2
overall_rate
# Out:
# Bailey High School       0.743067
# Cabrera High School      0.955867
# Figueroa High School     0.733639
# Ford High School         0.738043
# Griffin High School      0.952657
# Hernandez High School    0.738080
# Holden High School       0.943794
# Huang High School        0.735002
# Johnson High School      0.736400
# Pena High School         0.952703
# Rodriguez High School    0.732933
# Shelton High School      0.948609
# Thomas High School       0.952905
# Wilson High School       0.952037
# Wright High School       0.949722
# dtype: float64

# %%
#print(index)
dis_summary= pd.DataFrame ({

    "School Type": index,
    "Total Students": total_students_school,
    "Total School Budget": total_budget_school,
    "Per Student Budget": per_student_budget,
    "Average Math Score": average_math_school,
    "Average Reading Score": average_reading_school,
    "% Passing Math": percentage_math_school_2,
    "% Passing Reading": percentage_reading_school_2,
    "Overall Passing Rate": overall_rate

})


dis_summary = dis_summary[["School Type","Total Students","Total School Budget","Per Student Budget"
    ,"Average Math Score","Average Reading Score","% Passing Math","% Passing Reading","Overall Passing Rate"]]
dis_summary
# Out:
#                       School Type  Total Students  Total School Budget  \
# Bailey High School       District            4976            3124928.0
# Cabrera High School       Charter            1858            1081356.0
# Figueroa High School     District            2949            1884411.0
# Ford High School         District            2739            1763916.0
# Griffin High School       Charter            1468             917500.0
# Hernandez High School    District            4635            3022020.0
# Holden High School        Charter             427             248087.0
# Huang High School        District            2917            1910635.0
# Johnson High School      District            4761            3094650.0
# Pena High School          Charter             962             585858.0
# Rodriguez High School    District            3999            2547363.0
# Shelton High School       Charter            1761            1056600.0
# ...

# %% [markdown]
# ## Top Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the top five schools in overall passing rate

# %%
dis_summary.sort_values('Overall Passing Rate', ascending=False).head()
# Out:
#                     School Type  Total Students  Total School Budget  \
# Cabrera High School     Charter            1858            1081356.0
# Thomas High School      Charter            1635            1043130.0
# Pena High School        Charter             962             585858.0
# Griffin High School     Charter            1468             917500.0
# Wilson High School      Charter            2283            1319574.0
#
#                      Per Student Budget  Average Math Score  \
# Cabrera High School               582.0           83.061895
# Thomas High School                638.0           83.418349
# Pena High School                  609.0           83.839917
# Griffin High School               625.0           83.351499
# Wilson High School                578.0           83.274201
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780        0.941335           0.970398
# ...

# %%
# Out:
#                     School Type  Total Students Total School Budget  \
# Cabrera High School     Charter            1858       $1,081,356.00
# Thomas High School      Charter            1635       $1,043,130.00
# Pena High School        Charter             962         $585,858.00
# Griffin High School     Charter            1468         $917,500.00
# Wilson High School      Charter            2283       $1,319,574.00
#
#                     Per Student Budget  Average Math Score  \
# Cabrera High School            $582.00           83.061895
# Thomas High School             $638.00           83.418349
# Pena High School               $609.00           83.839917
# Griffin High School            $625.00           83.351499
# Wilson High School             $578.00           83.274201
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780       94.133477          97.039828
# ...

# %% [markdown]
# ## Bottom Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the five worst-performing schools

# %%
dis_summary.sort_values('Overall Passing Rate', ascending=True).head()
# Out:
#                       School Type  Total Students  Total School Budget  \
# Rodriguez High School    District            3999            2547363.0
# Figueroa High School     District            2949            1884411.0
# Huang High School        District            2917            1910635.0
# Johnson High School      District            4761            3094650.0
# Ford High School         District            2739            1763916.0
#
#                        Per Student Budget  Average Math Score  \
# Rodriguez High School               637.0           76.842711
# Figueroa High School                639.0           76.711767
# Huang High School                   655.0           76.629414
# Johnson High School                 650.0           77.072464
# Ford High School                    644.0           77.102592
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School              80.744686        0.663666
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
grade_9th = school_data_complete[school_data_complete['grade'] == '9th'].groupby('school_name')
grade_10th = school_data_complete[school_data_complete['grade'] == '10th'].groupby('school_name')
grade_11th = school_data_complete[school_data_complete['grade'] == '11th'].groupby('school_name')
grade_12th = school_data_complete[school_data_complete['grade'] == '12th'].groupby('school_name')
math_scores_df = pd.DataFrame({
    '9th': grade_9th['math_score'].mean(),
    '10th': grade_10th['math_score'].mean(),
    '11th': grade_11th['math_score'].mean(),
    '12th': grade_12th['math_score'].mean()},
    columns=['9th','10th','11th','12th'])
math_scores_df
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
reading_scores_df = pd.DataFrame({
    '9th': grade_9th['reading_score'].mean(),
    '10th': grade_10th['reading_score'].mean(),
    '11th': grade_11th['reading_score'].mean(),
    '12th': grade_12th['reading_score'].mean()},
    columns=['9th','10th','11th','12th'])
reading_scores_df
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# Sample bins. Feel free to create your own bins.
spending_bins = [0, 585, 615, 645, 675]
group_names = ["<$585", "$585-615", "$615-645", "$645-675"]

# %%
dis_summary["Spending Rate"] = pd.cut(dis_summary["Per Student Budget"], spending_bins, labels=group_names)
dis_summary.head()
# Out:
#                      School Type  Total Students  Total School Budget  \
# Bailey High School      District            4976            3124928.0
# Cabrera High School      Charter            1858            1081356.0
# Figueroa High School    District            2949            1884411.0
# Ford High School        District            2739            1763916.0
# Griffin High School      Charter            1468             917500.0
#
#                       Per Student Budget  Average Math Score  \
# Bailey High School                 628.0           77.048432
# Cabrera High School                582.0           83.061895
# Figueroa High School               639.0           76.711767
# Ford High School                   644.0           77.102592
# Griffin High School                625.0           83.351499
#
#                       Average Reading Score  % Passing Math  \
# Bailey High School                81.033963        0.666801
# ...

# %%
Grouped = dis_summary.groupby("Spending Rate")
Grouped.mean()
# Out:
#                Total Students  Total School Budget  Per Student Budget  \
# Spending Rate
# <$585             1592.000000         9.246042e+05          581.000000
# $585-615          1361.500000         8.212290e+05          604.500000
# $615-645          2961.000000         1.880208e+06          635.166667
# $645-675          4104.333333         2.675768e+06          652.333333
#
#                Average Math Score  Average Reading Score  % Passing Math  \
# Spending Rate
# <$585                   83.455399              83.933814        0.934601
# $585-615                83.599686              83.885211        0.942309
# $615-645                79.079225              81.891436        0.756682
# $645-675                76.997210              81.027843        0.661648
#
#                % Passing Reading  Overall Passing Rate
# Spending Rate
# <$585                   0.966109              0.950355
# $585-615                0.959003              0.950656
# ...

# %%
Grouped_2 = Grouped[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "Overall Passing Rate"]]
Grouped_2.mean()
# Out:
#                Average Math Score  Average Reading Score  % Passing Math  \
# Spending Rate
# <$585                   83.455399              83.933814        0.934601
# $585-615                83.599686              83.885211        0.942309
# $615-645                79.079225              81.891436        0.756682
# $645-675                76.997210              81.027843        0.661648
#
#                % Passing Reading  Overall Passing Rate
# Spending Rate
# <$585                   0.966109              0.950355
# $585-615                0.959003              0.950656
# $615-645                0.861066              0.808874
# $645-675                0.811340              0.736494

# %%
# Out:
#                                Average Math Score  Average Reading Score  \
# Spending Ranges (Per Student)
# <$585                                   83.455399              83.933814
# $585-615                                83.599686              83.885211
# $615-645                                79.079225              81.891436
# $645-675                                76.997210              81.027843
#
#                                % Passing Math  % Passing Reading  \
# Spending Ranges (Per Student)
# <$585                               93.460096          96.610877
# $585-615                            94.230858          95.900287
# $615-645                            75.668212          86.106569
# $645-675                            66.164813          81.133951
#
#                                % Overall Passing Rate
# Spending Ranges (Per Student)
# <$585                                       95.035486
# $585-615                                    95.065572
# ...

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Sample bins. Feel free to create your own bins.
size_bins = [0, 1000, 2000, 5000]
group_namess = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %%
BySchoolSize = dis_summary.copy()
BySchoolSize.head(2)
# Out:
#                     School Type  Total Students  Total School Budget  \
# Bailey High School     District            4976            3124928.0
# Cabrera High School     Charter            1858            1081356.0
#
#                      Per Student Budget  Average Math Score  \
# Bailey High School                628.0           77.048432
# Cabrera High School               582.0           83.061895
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Bailey High School               81.033963        0.666801           0.819333
# Cabrera High School              83.975780        0.941335           0.970398
#
#                      Overall Passing Rate Spending Rate
# Bailey High School               0.743067      $615-645
# Cabrera High School              0.955867         <$585

# %%
BySchoolSize["Size"] = pd.cut(BySchoolSize["Total Students"], size_bins, labels=group_namess)
BySchoolSize.head(2)
# Out:
#                     School Type  Total Students  Total School Budget  \
# Bailey High School     District            4976            3124928.0
# Cabrera High School     Charter            1858            1081356.0
#
#                      Per Student Budget  Average Math Score  \
# Bailey High School                628.0           77.048432
# Cabrera High School               582.0           83.061895
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Bailey High School               81.033963        0.666801           0.819333
# Cabrera High School              83.975780        0.941335           0.970398
#
#                      Overall Passing Rate Spending Rate                Size
# Bailey High School               0.743067      $615-645   Large (2000-5000)
# Cabrera High School              0.955867         <$585  Medium (1000-2000)

# %%
Grouped_Size = BySchoolSize.groupby("Size")
Grouped_Size.mean()
# Out:
#                     Total Students  Total School Budget  Per Student Budget  \
# Size
# Small (<1000)              694.500           416972.500             595.000
# Medium (1000-2000)        1704.400          1029597.200             605.600
# Large (2000-5000)         3657.375          2333437.125             635.375
#
#                     Average Math Score  Average Reading Score  % Passing Math  \
# Size
# Small (<1000)                83.821598              83.929843        0.935502
# Medium (1000-2000)           83.374684              83.864438        0.935997
# Large (2000-5000)            77.746417              81.344493        0.699634
#
#                     % Passing Reading  Overall Passing Rate
# Size
# Small (<1000)                0.960994              0.948248
# Medium (1000-2000)           0.967907              0.951952
# Large (2000-5000)            0.827666              0.763650

# %%
Grouped_Final_Size = Grouped_Size[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "Overall Passing Rate"]]
Grouped_Final_Size.mean()
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# Size
# Small (<1000)                83.821598              83.929843        0.935502
# Medium (1000-2000)           83.374684              83.864438        0.935997
# Large (2000-5000)            77.746417              81.344493        0.699634
#
#                     % Passing Reading  Overall Passing Rate
# Size
# Small (<1000)                0.960994              0.948248
# Medium (1000-2000)           0.967907              0.951952
# Large (2000-5000)            0.827666              0.763650

# %% [markdown]
# * Perform the same operations as above, based on school type.

# %%
ByType = dis_summary.copy()

# %%
ByType.head()
# Out:
#                      School Type  Total Students  Total School Budget  \
# Bailey High School      District            4976            3124928.0
# Cabrera High School      Charter            1858            1081356.0
# Figueroa High School    District            2949            1884411.0
# Ford High School        District            2739            1763916.0
# Griffin High School      Charter            1468             917500.0
#
#                       Per Student Budget  Average Math Score  \
# Bailey High School                 628.0           77.048432
# Cabrera High School                582.0           83.061895
# Figueroa High School               639.0           76.711767
# Ford High School                   644.0           77.102592
# Griffin High School                625.0           83.351499
#
#                       Average Reading Score  % Passing Math  \
# Bailey High School                81.033963        0.666801
# ...

# %%
ByType.columns
# Out:
# Index(['School Type', 'Total Students', 'Total School Budget',
#        'Per Student Budget', 'Average Math Score', 'Average Reading Score',
#        '% Passing Math', '% Passing Reading', 'Overall Passing Rate',
#        'Spending Rate'],
#       dtype='object')

# %%
ByType = ByType[["School Type", "Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "Overall Passing Rate"]]
ByType.head(2)
# Out:
#                     School Type  Average Math Score  Average Reading Score  \
# Bailey High School     District           77.048432              81.033963
# Cabrera High School     Charter           83.061895              83.975780
#
#                      % Passing Math  % Passing Reading  Overall Passing Rate
# Bailey High School         0.666801           0.819333              0.743067
# Cabrera High School        0.941335           0.970398              0.955867

# %%
ByType_Reset = ByType.mean().reset_index()

# %%
ByType_Reset.head()
# Out:
#                    index          0
# 0     Average Math Score  80.432530
# 1  Average Reading Score  82.529188
# 2         % Passing Math   0.809871
# 3      % Passing Reading   0.892190
# 4   Overall Passing Rate   0.851030

# %%
By_Type_Grouped = ByType_Reset.groupby("School Type")
By_Type_Grouped.mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-277-9d720862e4d5> in <module>
# ----> 1 By_Type_Grouped = ByType_Reset.groupby("School Type")
#       2 By_Type_Grouped.mean()
#
# ~\.conda\envs\PythonData\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7892             squeeze=squeeze,
#    7893             observed=observed,
# -> 7894             **kwargs
#    7895         )
#    7896
#
# ~\.conda\envs\PythonData\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2520         raise TypeError("invalid type: {}".format(obj))
#    2521
# -> 2522     return klass(obj, by, **kwds)
#
# ...

# %%
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421       93.620830
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  % Overall Passing Rate
# School Type
# Charter              96.586489               95.103660
# District             80.799062               73.673757
